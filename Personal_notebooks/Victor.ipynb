# %% [markdown]
# ## Imports

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# ## Loading the dataset

# %%
# Load the dataset
df = pd.read_csv(r"C:\Users\user\Desktop\Phase 2 Project\Group18_Phase2\data\kc_house_data.csv")
df
# Out:
#                id        date     price  bedrooms  bathrooms  sqft_living  \
# 0      7129300520  10/13/2014  221900.0         3       1.00         1180
# 1      6414100192   12/9/2014  538000.0         3       2.25         2570
# 2      5631500400   2/25/2015  180000.0         2       1.00          770
# 3      2487200875   12/9/2014  604000.0         4       3.00         1960
# 4      1954400510   2/18/2015  510000.0         3       2.00         1680
# ...           ...         ...       ...       ...        ...          ...
# 21592   263000018   5/21/2014  360000.0         3       2.50         1530
# 21593  6600060120   2/23/2015  400000.0         4       2.50         2310
# 21594  1523300141   6/23/2014  402101.0         2       0.75         1020
# 21595   291310100   1/16/2015  400000.0         3       2.50         1600
# 21596  1523300157  10/15/2014  325000.0         2       0.75         1020
#
#        sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# ...

# %% [markdown]
# ## Data Understanding

# %%
# Display the first few rows of our dataset
df.head()
# Out:
#            id        date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  10/13/2014  221900.0         3       1.00         1180
# 1  6414100192   12/9/2014  538000.0         3       2.25         2570
# 2  5631500400   2/25/2015  180000.0         2       1.00          770
# 3  2487200875   12/9/2014  604000.0         4       3.00         1960
# 4  1954400510   2/18/2015  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0         NaN   0.0  ...      7        1180            0.0
# 1      7242     2.0         0.0   0.0  ...      7        2170          400.0
# 2     10000     1.0         0.0   0.0  ...      6         770            0.0
# 3      5000     1.0         0.0   0.0  ...      7        1050          910.0
# 4      8080     1.0         0.0   0.0  ...      8        1680            0.0
#
#   yr_built  yr_renovated  zipcode      lat     long  sqft_living15  sqft_lot15
# ...

# %%
# Summary of the data
df.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.159700e+04  2.159700e+04  21597.000000  21597.000000  21597.000000
# mean   4.580474e+09  5.402966e+05      3.373200      2.115826   2080.321850
# std    2.876736e+09  3.673681e+05      0.926299      0.768984    918.106125
# min    1.000102e+06  7.800000e+04      1.000000      0.500000    370.000000
# 25%    2.123049e+09  3.220000e+05      3.000000      1.750000   1430.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.159700e+04  21597.000000  19221.000000  21534.000000  21597.000000
# mean   1.509941e+04      1.494096      0.007596      0.233863      3.409825
# ...

# %%
# Check for missing values
df.isnull().sum()
# Out:
# id                  0
# date                0
# price               0
# bedrooms            0
# bathrooms           0
# sqft_living         0
# sqft_lot            0
# floors              0
# waterfront       2376
# view               63
# condition           0
# grade               0
# sqft_above          0
# sqft_basement       0
# yr_built            0
# yr_renovated     3842
# zipcode             0
# lat                 0
# long                0
# sqft_living15       0
# sqft_lot15          0
# dtype: int64

# %%
# Visualize the distribution of the target variable(house prices)
plt.figure(figsize=(10,6))
sns.histplot(df["price"], bins=50, kde=True)
plt.title("Distribution of house prices")
plt.xlabel("Price")
plt.ylabel("Frequency")
plt.show()

# %%
# Visualize correlations between features
plt.figure(figsize=(12, 10))
sns.heatmap(df.corr(), annot=True, cmap="coolwarm", linewidths=0.5)
plt.title("correlation matrix")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ## Data Preparation

# %%
# Checking for missing data
df.isnull().sum()
# Out:
# id                  0
# date                0
# price               0
# bedrooms            0
# bathrooms           0
# sqft_living         0
# sqft_lot            0
# floors              0
# waterfront       2376
# view               63
# condition           0
# grade               0
# sqft_above          0
# sqft_basement       0
# yr_built            0
# yr_renovated     3842
# zipcode             0
# lat                 0
# long                0
# sqft_living15       0
# sqft_lot15          0
# dtype: int64

# %%
# Convert categorical data that we will need 
df["waterfront"] = df["waterfront"].apply(lambda x: 1 if x == "yes" else 0)
df["view"] = df["view"].apply(lambda x:1 if x =="yes" else 0 )

# %%
# Confirm that data has been converted
df.isnull().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
# Remove the first two columns we wont be using and also the prediction target column(price) to check for correlation between predictor variables
data_pred = df.iloc[:,3:21]
data_pred.head()
# Out:
#    bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  view  \
# 0         3       1.00         1180      5650     1.0           0     0
# 1         3       2.25         2570      7242     2.0           0     0
# 2         2       1.00          770     10000     1.0           0     0
# 3         4       3.00         1960      5000     1.0           0     0
# 4         3       2.00         1680      8080     1.0           0     0
#
#    condition  grade  sqft_above sqft_basement  yr_built  yr_renovated  \
# 0          3      7        1180           0.0      1955             0
# 1          3      7        2170         400.0      1951             0
# 2          3      6         770           0.0      1933             0
# 3          5      7        1050         910.0      1965             0
# 4          3      8        1680           0.0      1987             0
#
#    zipcode      lat     long  sqft_living15  sqft_lot15
# ...

# %%
# Check for correlation between variables
data_pred.corr()
# Out:
#                bedrooms  bathrooms  sqft_living  sqft_lot    floors  \
# bedrooms       1.000000   0.514508     0.578212  0.032471  0.177944
# bathrooms      0.514508   1.000000     0.755758  0.088373  0.502582
# sqft_living    0.578212   0.755758     1.000000  0.173453  0.353953
# sqft_lot       0.032471   0.088373     0.173453  1.000000 -0.004814
# floors         0.177944   0.502582     0.353953 -0.004814  1.000000
# waterfront          NaN        NaN          NaN       NaN       NaN
# view                NaN        NaN          NaN       NaN       NaN
# condition      0.026496  -0.126479    -0.059445 -0.008830 -0.264075
# grade          0.356563   0.665838     0.762779  0.114731  0.458794
# sqft_above     0.479386   0.686668     0.876448  0.184139  0.523989
# yr_built       0.155670   0.507173     0.318152  0.052946  0.489193
# yr_renovated        NaN        NaN          NaN       NaN       NaN
# zipcode       -0.154092  -0.204786    -0.199802 -0.129586 -0.059541
# ...

# %%
abs(data_pred.corr()) > 0.5
# Out:
#                bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# bedrooms           True       True         True     False   False       False
# bathrooms          True       True         True     False    True       False
# sqft_living        True       True         True     False   False       False
# sqft_lot          False      False        False      True   False       False
# floors            False       True        False     False    True       False
# waterfront        False      False        False     False   False       False
# view              False      False        False     False   False       False
# condition         False      False        False     False   False       False
# grade             False       True         True     False   False       False
# sqft_above        False       True         True     False    True       False
# yr_built          False       True        False     False   False       False
# ...

# %%
# save absolute value of correlation matrix as a data frame
# converts all values to absolute value
# stacks the row:column pairs into a multindex
# reset the index to set the multindex to seperate columns
# sort values. 0 is the column automatically generated by the stacking

df=data_pred.corr().abs().stack().reset_index().sort_values(0, ascending=False)

# zip the variable name columns (Which were only named level_0 and level_1 by default) in a new column named "pairs"
df['pairs'] = list(zip(df.level_0, df.level_1))

# set index to pairs
df.set_index(['pairs'], inplace = True)

#drop level columns
df.drop(columns=['level_1', 'level_0'], inplace = True)

# rename correlation column as cc rather than 0
df.columns = ['cc']

# drop duplicates. This could be dangerous if you have variables perfectly correlated with variables other than themselves.
# for the sake of exercise, kept it in.
df.drop_duplicates(inplace=True)

# %%
df[(df.cc>.5) & (df.cc <1)]
# Out:
#                                     cc
# pairs
# (sqft_living, sqft_above)     0.876448
# (grade, sqft_living)          0.762779
# (sqft_living15, sqft_living)  0.756402
# (sqft_above, grade)           0.756073
# (sqft_living, bathrooms)      0.755758
# (sqft_living15, sqft_above)   0.731767
# (sqft_lot15, sqft_lot)        0.718204
# (sqft_living15, grade)        0.713867
# (sqft_above, bathrooms)       0.686668
# (grade, bathrooms)            0.665838
# (sqft_living, bedrooms)       0.578212
# (sqft_living15, bathrooms)    0.569884
# (long, zipcode)               0.564259
# (sqft_above, floors)          0.523989
# (bedrooms, bathrooms)         0.514508
# (yr_built, bathrooms)         0.507173
# (floors, bathrooms)           0.502582

# %%
sns.heatmap(data_pred.corr(), center=0);
